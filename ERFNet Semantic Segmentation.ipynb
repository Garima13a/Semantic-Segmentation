# %% [markdown]
# <h1><center>Semantic Segmentation: Let's classify each pixel</center></h1>

# %% [markdown]
# Q.) What is segmentation ?
#
# The aim of **segmentation** is to partition an image into a collection of set of pixels.
#
# What could be such a collection of pixels:
#
# * Meaningful regions (coherent objects)
#
# * Linear Structures (line, curve,...)
#
# * Shapes (circles, ellipses,...)
#
# <img src="img/seg.png">

# %% [markdown]
# But that's not all. What if we want to explore more and want know pixels which occupy which category amongst the defined ones.
#
# **Semantic Segmentation:** Semantic Segmentation of an image is the task to assign each pixel in the input image a semantic class in order to get a pixel-wise dense classification.
# <img src="img/ss_tot.png">
#
# Traditonal methods do feature representation and go up in a hierarchial way to do the segmentation.With the popularity of deep learning in recent years, many semantic segmentation problems are being tackled using deep architectures, most often Convolutional Neural Nets, which surpass other approaches by a large margin in terms of accuracy and efficiency. Breakthrough came in this field of semantic segmentation when **Fully Convolutional Networks** were first introduced in 2014 **Long et. al.** to perform end-to-end segmentation of natural images.
# <img src="img/fcn.png">

# %% [markdown]
# <h1><center>Applications of Semantic Segmentation</center></h1>

# %% [markdown]
# Semantic segmentation is generally used for:
#
# -  Autonomous driving (Scene understanding)
# -  Medical image segmentation
# -  Robot Vision and Understanding
#
# The importance of scene understanding as a core computer vision problem is highlighted by the fact that an increasing number of applications nourish from inferring knowledge from imagery. Some of those applications include self-driving vehicles, human-computer interaction, virtual reality etc.
#
# We are going to look at some of the dataset which is widely used for the task of scene understanding and hence apply our semantic segmnetation algorithm on the same.

# %% [markdown]
# ## Cityscapes Dataset

# %% [markdown]
# **The Cityscapes Dataset** focuses on semantic understanding of urban street scenes. This dataset has been collected over 50 cities of Germany in different settings. It contains 2975 training and 500 validation images with publicly available annotations, as well as 1525 test images. The dataset contains fine and coarse annotations that have been manually annotated.
#
# The authors came up with 30 visual classes for annotation, which are grouped  into  eight  categories: flat, construction, nature, vehicle, sky, object, human, and void. (Please see the image below from their paper!!)
#
# <img src="img/class.png">
#
# Image | Color Mask
# - | -
# ![alt](img/aachen.png) | ![alt](img/aachen_color.png)
# ![alt](img/zurich.png) | ![alt](img/zurich_color.png)

# %% [markdown]
# ## Indian Driving Dataset

# %% [markdown]
# **Indian Driving Dataset: Lite** or abbreviated IDD is a dataset targetted to acquire images in natural unconstrained setting available in India. It comprises 10,003 images from 182 driving sequences, divided in 6,993/981/2,029 images for training, validation and test, respectively. The dataset has multi label level hierarchy to report results respectively.
#   * L4: 30 labels
#   * L3: 26 labels
#   * L2: 16 labels
#   * L1: 7 labels
#
# Group of labels can be groupped together to form one form of label.
#
# <img src="img/label_idd.png">
#
#
# <img src="img/idd_img.png">
# <img src="img/idd_lab_2.png">
#
# We will be training and testing our code on IDD Lite which is a subsampled version of the dataset. We believe that this
# will enable quick prototyping useful in optimum parameter and architecture search, and encourage deployment on low
# resource hardware.

# %% [markdown]
# ### Metrics used in evaluation of Semantic Segmentation algorithm

# %% [markdown]
# The different metrics used for evaluating semantic segmenatation algorithm are given below in the picture:
# <center> Pixel Accuracy </center> | <center> Mean Accuracy </center>
# - | -
# ![alt](img/pa_ss.png) | ![alt](img/ma_ss.png)
#
# <center> Mean IOU </center> | <center> Frequency Weighted IOU </center>
# - | -
# ![alt](img/miou_ss.png) | ![alt](img/fiou_ss.png)

# %% [markdown]
# <h1><center> Model Architectures for Semantic Segmentation</h1></center>

# %% [markdown]
# In a nutshell, there are two types of architectures that are prominent in semantic segmentation.
#
# * Encoder Decoder Based Architecture
#
# **Encoder**: A pre-trained classification network like VGG/ResNet followed by a decoder network.
#
# **Decoder**: The task of the decoder is to semantically project the discriminative features (lower resolution) learnt by the encoder onto the pixel space (higher resolution) to get a dense classification. This is where most architectures differ. Some architectures directly upsample the feature map and some use complex architecture to get more refined outputs.
#
#
# * Spatial Pyramid Pooling Based Architecture
#
#   **Extract features from CNN based architecture**
#
#   **Sub region pooling**
#
#   **1X1 Convolution for feature concatenation/ dimension reduction**
#
#   **Interpolation for upsampling**
#
# Take a look at the architectures !!
#
# <center> Spatial Pyramid Pooling Architecture</center> | <center> Encoder Decoder Architecture </center>
# - | -
# ![alt](img/spp.png) | ![alt](img/enc.png)
#
#
# <img src="img/spp_2.png">
# <img src="img/encode_ss.jpeg">

# %%
#Importing the necessary libraries needed for processing

import random
import time
import numpy as np
import torch
print(torch.__version__)
import math
# Out:
# 1.0.0

# %%
#Importing library to do image related operations
from PIL import Image, ImageOps

# %%
#Importing the important functionalities of Pytorch such as the dataloader, Variable, transform's 
#and optimizer related functions.

from torch.optim import SGD, Adam, lr_scheduler
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.transforms import  Resize
from torchvision.transforms import ToTensor, ToPILImage

# %%
# Importing the dataset class for VOC12 and cityscapes
from dataset import cityscapes
from dataset import idd_lite

import sys
print(sys.executable)

#Importing the Relabel, ToLabel and Colorize class from transform.py file
from transform import Relabel, ToLabel, Colorize
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# /users/school/sources/cv-19/venv/bin/python3

# %%
import importlib
from iouEval import iouEval, getColorEntry #importing iouEval class from the iouEval.py file
from shutil import copyfile

# %% [markdown]
# ### A few global parameters ###

# %%
NUM_CHANNELS = 3 #RGB Images
NUM_CLASSES = 8 #IDD Lite has 8 labels or Level1 hierarchy of labels
USE_CUDA = torch.cuda.is_available() 
IMAGE_HEIGHT = 160
DATA_ROOT = '/tmp/school/6-segmentation/user/1/6-segmentation/idd1_lite'
BATCH_SIZE = 2
NUM_WORKERS = 4
NUM_EPOCHS = 100
ENCODER_ONLY = True
device = torch.device("cuda" )
#device = 'cuda'
color_transform = Colorize(NUM_CLASSES)
image_transform = ToPILImage()

# %%
IOUTRAIN = False
IOUVAL = True

# %%
#Augmentations - different function implemented to perform random augments on both image and target
class MyCoTransform(object):
    def __init__(self, enc, augment=True, height=160):
        self.enc=enc
        self.augment = augment
        self.height = height
        pass
    def __call__(self, input, target):
        # Resizing data to required size
        input =  Resize((self.height,320), Image.BILINEAR)(input)
        target = Resize((self.height,320), Image.NEAREST)(target)

        if(self.augment):
            # Random horizontal flip
            hflip = random.random()
            if (hflip < 0.5):
                input = input.transpose(Image.FLIP_LEFT_RIGHT)
                target = target.transpose(Image.FLIP_LEFT_RIGHT)
            
            #Random translation 0-2 pixels (fill rest with padding)
            transX = random.randint(0, 2) 
            transY = random.randint(0, 2)

            input = ImageOps.expand(input, border=(transX,transY,0,0), fill=0)
            target = ImageOps.expand(target, border=(transX,transY,0,0), fill=7) #pad label filling with 7
            input = input.crop((0, 0, input.size[0]-transX, input.size[1]-transY))
            target = target.crop((0, 0, target.size[0]-transX, target.size[1]-transY))   

        input = ToTensor()(input)
        
        target = ToLabel()(target)
        
        target = Relabel(255,7)(target)
        return input, target

# %% [markdown]
# ### Loading Data
#
# We'll follow pytorch recommended semantics, and use a dataloader to load the data.

# %%
best_acc = 0

co_transform = MyCoTransform(ENCODER_ONLY, augment=True, height=IMAGE_HEIGHT)
co_transform_val = MyCoTransform(ENCODER_ONLY, augment=False, height=IMAGE_HEIGHT)

#train data
dataset_train = idd_lite(DATA_ROOT, co_transform, 'train')
print(len(dataset_train))
#test data
dataset_val = idd_lite(DATA_ROOT, co_transform_val, 'val')
print(len(dataset_val))


# NOTE: PLEASE DON'T CHANGE batch_size and num_workers here. We have limited resources.
loader_train = DataLoader(dataset_train, num_workers=NUM_WORKERS, batch_size=BATCH_SIZE, shuffle=True)
loader_val = DataLoader(dataset_val, num_workers=NUM_WORKERS, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# 673
# 110

# %% [markdown]
# ## Cross Entropy  Loss ##
# Negative Log Loss   |Plot of -log(x) vs x
# - | -
# ![alt](img/nll.png) | ![alt](img/nll-log.png)
#
# The negative log-likelihood becomes unhappy at smaller values, where it can reach infinite unhappiness (that’s too sad), and becomes less unhappy at larger values. Because we are summing the loss function to all the correct classes, what’s actually happening is that whenever the network assigns high confidence at the correct class, the unhappiness is low, but when the network assigns low confidence at the correct class, the unhappiness is high.

# %%
criterion = torch.nn.CrossEntropyLoss()

# %% [markdown]
# ### Take a look at the data? ###

# %%
#get some random training images
print(len(loader_train))
#print(len(loader_val))
dataiter = iter(loader_train)
#print(dataiter.next())
(images, labels) = dataiter.next()
#for step, (images, labels) in enumerate(loader_train):
plt.figure()
plt.imshow(ToPILImage()(images[0].cpu()))
plt.figure()
plt.imshow(ToPILImage()(Colorize()(labels[0].cpu())))  
#break
# Out:
# 337

# %% [markdown]
# ## Model ##

# %% [markdown]
# In this lab, we would be using [ERFNET](http://www.robesafe.uah.es/personal/eduardo.romera/pdfs/Romera17iv.pdf)
# model, which is an encoder-decoder architecture. Please see the image below !!
# <img src="img/erfnet.png">
# <img src="img/erfnet-model.png">
#
#
# We show two ways to train the **ERFNET architecture** on a standard dataset:
#
# -  Training the encoder and decoder from the scratch.
# -  Just training the encoder and then bilinearly upsampling the encoder's output to match input image size .
#
# ERFNET reformulates the **Resnet architecture** into novel 1-d bottleneck and non bottleneck 1-d blocks (See more in the paper). Because of the ResNet architecture, the information of semantic boundary is passed through the residual mappings and hence the need for explicit skip connections is not required.
#
# Downsampling (reducing the spatial resolution) has the drawback of reducing the accuracy (coarser outputs), but it
# also  has  two  benefits:  it  lets  the  deeper  layers  gather  more context  (to  improve  classification)  and  it  helps  to  reduce computation.
#
# Power vs FPS | Category MIOU vs FPS
# - | -
# ![alt](img/comp_ss.png) | ![alt](img/comp_ss_2.png)

# %%
model_file = importlib.import_module('erfnet')
model = model_file.Net(NUM_CLASSES).to(device)

# %% [markdown]
# ### Optimizer ###

# %%
# We use adam optimizer. It can be replaced with SGD and other optimizers
optimizer = Adam(model.parameters(), 5e-4, (0.9, 0.999),  eps=1e-08, weight_decay=1e-4) 
start_epoch = 1

# %%
print(device)
# Out:
# cuda

# %% [markdown]
# ### Training Procedure ###

# %%
import os
steps_loss = 50
my_start_time = time.time()
for epoch in range(start_epoch, NUM_EPOCHS+1):
    print("----- TRAINING - EPOCH", epoch, "-----")

    epoch_loss = []
    time_train = []

    doIouTrain = IOUTRAIN   
    doIouVal =  IOUVAL      

    if (doIouTrain):
        iouEvalTrain = iouEval(NUM_CLASSES)

    model.train()
    for step, (images, labels) in enumerate(loader_train):

        start_time = time.time()
        inputs = images.to(device)
        targets = labels.to(device)
    
        outputs = model(inputs, only_encode=ENCODER_ONLY)

        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        loss = criterion(outputs, targets[:, 0])
        loss.backward()
        optimizer.step()

        epoch_loss.append(loss.item())
        time_train.append(time.time() - start_time)

        if (doIouTrain):
            #start_time_iou = time.time()
            iouEvalTrain.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
            #print ("Time to add confusion matrix: ", time.time() - start_time_iou)      

        # print statistics
        if steps_loss > 0 and step % steps_loss == 0:
            average = sum(epoch_loss) / len(epoch_loss)
            print('loss: {average:0.4} (epoch: {epoch}, step: {step})', "// Avg time/img: %.4f s" % (sum(time_train) / len(time_train) / BATCH_SIZE))


    average_epoch_loss_train = sum(epoch_loss) / len(epoch_loss)

    iouTrain = 0
    if (doIouTrain):
        iouTrain, iou_classes = iouEvalTrain.getIoU()
        iouStr = getColorEntry(iouTrain)+'{:0.2f}'.format(iouTrain*100) + '\033[0m'
        print ("EPOCH IoU on TRAIN set: ", iouStr, "%")  
my_end_time = time.time()
print(my_end_time - my_start_time)
# Out:
# ----- TRAINING - EPOCH 1 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0319 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0228 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0234 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0241 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0229 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0222 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0220 s
# ----- TRAINING - EPOCH 2 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0242 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0208 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0200 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0197 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0199 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0201 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0200 s
# ----- TRAINING - EPOCH 3 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0224 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0206 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0205 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0212 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0212 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0215 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0219 s
# ----- TRAINING - EPOCH 4 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0295 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0238 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0219 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0210 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0213 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0216 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0218 s
# ----- TRAINING - EPOCH 5 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0213 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0222 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0210 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0209 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0210 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0212 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0209 s
# ----- TRAINING - EPOCH 6 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0231 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0201 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0209 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0205 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0207 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0204 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0202 s
# ----- TRAINING - EPOCH 7 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0301 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0216 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0219 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0221 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0216 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0212 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0209 s
# ----- TRAINING - EPOCH 8 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0255 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0208 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0202 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0200 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0200 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0205 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0209 s
# ----- TRAINING - EPOCH 9 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0215 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0219 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0208 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0203 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0203 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0207 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0210 s
# ----- TRAINING - EPOCH 10 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0243 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0224 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0230 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0220 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0216 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0216 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0219 s
# ----- TRAINING - EPOCH 11 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0323 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0269 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0268 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0277 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0266 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0254 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0245 s
# ----- TRAINING - EPOCH 12 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0235 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0217 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0241 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0243 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0249 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0247 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0238 s
# ----- TRAINING - EPOCH 13 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0216 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0223 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0279 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0300 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0351 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0383 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0404 s
# ----- TRAINING - EPOCH 14 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0507 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0470 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0404 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0417 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0383 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0388 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0365 s
# ----- TRAINING - EPOCH 15 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0236 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0213 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0204 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0225 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0234 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0240 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0239 s
# ----- TRAINING - EPOCH 16 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0262 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0240 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0291 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0315 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0339 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0348 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0330 s
# ----- TRAINING - EPOCH 17 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0216 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0300 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0279 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0271 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0295 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0313 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0320 s
# ----- TRAINING - EPOCH 18 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0341 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0373 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0327 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0327 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0331 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0335 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0337 s
# ----- TRAINING - EPOCH 19 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0337 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0335 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0334 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0320 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0321 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0318 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0314 s
# ----- TRAINING - EPOCH 20 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0298 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0275 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0281 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0282 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0281 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0281 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0280 s
# ----- TRAINING - EPOCH 21 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0285 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0275 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0274 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0310 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0323 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0334 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0336 s
# ----- TRAINING - EPOCH 22 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0422 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0317 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0277 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0280 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0300 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0314 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0320 s
# ----- TRAINING - EPOCH 23 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0325 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0300 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0290 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0294 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0311 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0319 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0334 s
# ----- TRAINING - EPOCH 24 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0343 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0244 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0242 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0261 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0263 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0248 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0238 s
# ----- TRAINING - EPOCH 25 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0222 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0304 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0291 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0290 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0291 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0284 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0276 s
# ----- TRAINING - EPOCH 26 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0369 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0367 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0350 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0351 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0348 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0336 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0328 s
# ----- TRAINING - EPOCH 27 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0330 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0327 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0338 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0338 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0317 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0333 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0340 s
# ----- TRAINING - EPOCH 28 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0330 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0263 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0267 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0242 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0230 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0235 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0234 s
# ----- TRAINING - EPOCH 29 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0286 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0200 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0197 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0196 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0195 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0195 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0198 s
# ----- TRAINING - EPOCH 30 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0269 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0278 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0265 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0245 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0239 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0246 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0247 s
# ----- TRAINING - EPOCH 31 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0233 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0199 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0278 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0305 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0318 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0327 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0335 s
# ----- TRAINING - EPOCH 32 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0339 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0297 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0305 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0329 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0329 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0316 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0307 s
# ----- TRAINING - EPOCH 33 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0252 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0199 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0202 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0207 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0213 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0217 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0218 s
# ----- TRAINING - EPOCH 34 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0241 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0228 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0222 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0213 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0208 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0211 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0218 s
# ----- TRAINING - EPOCH 35 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0210 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0204 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0223 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0229 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0239 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0266 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0274 s
# ----- TRAINING - EPOCH 36 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0295 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0302 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0299 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0293 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0294 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0295 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0309 s
# ----- TRAINING - EPOCH 37 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0353 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0331 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0349 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0338 s
# ----- TRAINING - EPOCH 44 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0288 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0310 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0295 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0263 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0246 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0236 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0230 s
# ----- TRAINING - EPOCH 45 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0219 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0261 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0256 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0252 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0236 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0226 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0220 s
# ----- TRAINING - EPOCH 46 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0274 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0250 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0265 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0260 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0257 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0256 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0273 s
# ----- TRAINING - EPOCH 47 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0270 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0199 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0194 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0192 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0191 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0191 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0191 s
# ----- TRAINING - EPOCH 48 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0282 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0278 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0340 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0348 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0333 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0323 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0320 s
# ----- TRAINING - EPOCH 49 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0360 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0417 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0431 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0435 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0434 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0432 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0423 s
# ----- TRAINING - EPOCH 50 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0240 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0232 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0220 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0211 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0207 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0204 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0207 s
# ----- TRAINING - EPOCH 51 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0236 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0217 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0227 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0216 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0211 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0207 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0205 s
# ----- TRAINING - EPOCH 52 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0210 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# ----- TRAINING - EPOCH 53 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0207 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0190 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# ----- TRAINING - EPOCH 54 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0321 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0427 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0401 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0372 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0361 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0377 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0389 s
# ----- TRAINING - EPOCH 55 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0402 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0391 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0395 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0381 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0380 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0390 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0397 s
# ----- TRAINING - EPOCH 56 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0422 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0278 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0283 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0279 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0299 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0314 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0330 s
# ----- TRAINING - EPOCH 57 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0279 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0360 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0371 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0386 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0393 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0394 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0390 s
# ----- TRAINING - EPOCH 58 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0385 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0226 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0230 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0225 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0240 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0273 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0286 s
# ----- TRAINING - EPOCH 59 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0234 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0196 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0193 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0217 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0235 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0239 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0231 s
# ----- TRAINING - EPOCH 60 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0230 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0250 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0262 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0268 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0271 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0273 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0279 s
# ----- TRAINING - EPOCH 61 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0264 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0251 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0229 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0240 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0264 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0282 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0298 s
# ----- TRAINING - EPOCH 62 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0253 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0282 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0326 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0349 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0311 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0287 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0273 s
# ----- TRAINING - EPOCH 63 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0402 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0420 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0393 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0371 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0372 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0365 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0353 s
# ----- TRAINING - EPOCH 64 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0264 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0396 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0407 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0377 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0393 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0399 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0405 s
# ----- TRAINING - EPOCH 65 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0322 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0342 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0305 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0267 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0248 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0236 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0228 s
# ----- TRAINING - EPOCH 66 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0258 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0197 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0193 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0193 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0192 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0195 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0194 s
# ----- TRAINING - EPOCH 67 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0262 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0295 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0301 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0292 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0287 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0293 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0296 s
# ----- TRAINING - EPOCH 68 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0283 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0270 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0299 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0341 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0329 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0336 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0331 s
# ----- TRAINING - EPOCH 69 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0300 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0203 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0198 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0197 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0202 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0212 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0210 s
# ----- TRAINING - EPOCH 70 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0309 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0295 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0276 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0270 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0261 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0247 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0237 s
# ----- TRAINING - EPOCH 71 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0211 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0190 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# ----- TRAINING - EPOCH 72 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0209 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0189 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0190 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0190 s
# ----- TRAINING - EPOCH 73 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0273 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0196 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0195 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0195 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0195 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0194 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0219 s
# ----- TRAINING - EPOCH 74 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0364 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0282 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0277 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0266 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0260 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0251 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0247 s
# ----- TRAINING - EPOCH 75 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0298 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0281 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0266 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0261 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0258 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0256 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0277 s
# ----- TRAINING - EPOCH 76 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0281 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0316 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0302 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0303 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0318 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0314 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0308 s
# ----- TRAINING - EPOCH 77 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0292 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0301 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0304 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0312 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0340 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0342 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0351 s
# ----- TRAINING - EPOCH 78 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0281 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0330 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0307 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0336 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0331 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0335 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0334 s
# ----- TRAINING - EPOCH 79 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0375 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0280 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0264 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0259 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0267 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0269 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0266 s
# ----- TRAINING - EPOCH 80 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0312 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0243 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0243 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0241 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0229 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0222 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0218 s
# ----- TRAINING - EPOCH 81 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0314 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0251 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0223 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0221 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0268 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0293 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0310 s
# ----- TRAINING - EPOCH 82 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0244 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0261 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0269 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0270 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0299 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0320 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0317 s
# ----- TRAINING - EPOCH 83 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0329 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0288 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0312 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0308 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0323 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0345 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0362 s
# ----- TRAINING - EPOCH 84 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0290 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0227 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0259 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0254 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0254 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0249 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0250 s
# ----- TRAINING - EPOCH 85 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0310 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0242 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0249 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0265 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0278 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0285 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0298 s
# ----- TRAINING - EPOCH 86 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0385 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0302 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0296 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0292 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0291 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0291 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0290 s
# ----- TRAINING - EPOCH 87 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0286 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0353 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0322 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0324 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0306 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0295 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0289 s
# ----- TRAINING - EPOCH 88 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0341 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0346 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0390 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0404 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0415 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0422 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0423 s
# ----- TRAINING - EPOCH 89 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0334 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0329 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0347 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0375 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0367 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0381 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0392 s
# ----- TRAINING - EPOCH 90 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0362 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0393 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0408 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0398 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0380 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0380 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0383 s
# ----- TRAINING - EPOCH 91 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0312 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0371 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0340 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0328 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0332 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0317 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0307 s
# ----- TRAINING - EPOCH 92 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0373 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0407 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0377 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0356 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0332 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0311 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0291 s
# ----- TRAINING - EPOCH 93 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0270 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0246 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0244 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0244 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0243 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0245 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0246 s
# ----- TRAINING - EPOCH 94 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0338 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0344 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0343 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0314 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0294 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0312 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0320 s
# ----- TRAINING - EPOCH 95 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0305 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0374 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0366 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0360 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0378 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0371 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0371 s
# ----- TRAINING - EPOCH 96 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0309 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0262 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0240 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0232 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0242 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0251 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0254 s
# ----- TRAINING - EPOCH 97 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0302 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0362 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0376 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0393 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0386 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0373 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0379 s
# ----- TRAINING - EPOCH 98 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0360 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0371 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0350 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0375 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0388 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0377 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0361 s
# ----- TRAINING - EPOCH 99 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0285 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0265 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0250 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0247 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0245 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0242 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0242 s
# ----- TRAINING - EPOCH 100 -----
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0292 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0261 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0257 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0319 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0322 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0326 s
# loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0328 s
# 1959.7724242210388

# %% [markdown]
# ### Validation ###

# %%
#Validate on val images after each epoch of training
print("----- VALIDATING - EPOCH", epoch, "-----")
model.eval()
epoch_loss_val = []
time_val = []

if (doIouVal):
    iouEvalVal = iouEval(NUM_CLASSES)

for step, (images, labels) in enumerate(loader_val):
    start_time = time.time()

    inputs = images.to(device)    
    targets = labels.to(device)
    
    with torch.no_grad():
        outputs = model(inputs, only_encode=ENCODER_ONLY) 
        #outputs = model(inputs)
    loss = criterion(outputs, targets[:, 0])
    epoch_loss_val.append(loss.item())
    time_val.append(time.time() - start_time)


    #Add batch to calculate TP, FP and FN for iou estimation
    if (doIouVal):
        #start_time_iou = time.time()
        iouEvalVal.addBatch(outputs.max(1)[1].unsqueeze(1).data, targets.data)
        #print ("Time to add confusion matrix: ", time.time() - start_time_iou)
        
    if steps_loss > 0 and step % steps_loss == 0:
        average = sum(epoch_loss_val) / len(epoch_loss_val)
        print('VAL loss: {average:0.4} (epoch: {epoch}, step: {step})', 
                "// Avg time/img: %.4f s" % (sum(time_val) / len(time_val) / BATCH_SIZE))


average_epoch_loss_val = sum(epoch_loss_val) / len(epoch_loss_val)

iouVal = 0
if (doIouVal):

    iouVal, iou_classes = iouEvalVal.getIoU()
    print(iou_classes)
    iouStr = getColorEntry(iouVal)+'{:0.2f}'.format(iouVal*100) + '\033[0m'
    print ("EPOCH IoU on VAL set: ", iouStr, "%")
# Out:
# ----- VALIDATING - EPOCH 100 -----
# VAL loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0128 s
# VAL loss: {average:0.4} (epoch: {epoch}, step: {step}) // Avg time/img: 0.0099 s
# tensor([0.9159, 0.2645, 0.4062, 0.6874, 0.3390, 0.7391, 0.8800],
#        dtype=torch.float64)
# EPOCH IoU on VAL set:  60.46 %

# %% [markdown]
#  ### Visualizing the Output###

# %%
# Qualitative Analysis
dataiter = iter(loader_val)
images, labels = dataiter.next()

if USE_CUDA:
    images = images.to(device)

inputs = images.to(device)

with torch.no_grad():
    outputs = model(inputs, only_encode=ENCODER_ONLY)

label = outputs[0].max(0)[1].byte().cpu().data

label_color = Colorize()(label.unsqueeze(0))

label_save = ToPILImage()(label_color)
plt.figure()
plt.imshow(ToPILImage()(images[0].cpu()))
plt.figure()
plt.imshow(label_save)
